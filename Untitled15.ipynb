# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya0396/weatherproject/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame({'Roll no':[1,2,3,4],'Name':['Aditya','Shubham','Jayesh','Yash'],'Div':['A','B','C','D'],'Marks':[98,87,79,80]})
print(df)
df.isnull()
df.sum
# Out:
#    Roll no     Name Div  Marks
# 0        1   Aditya   A     98
# 1        2  Shubham   B     87
# 2        3   Jayesh   C     79
# 3        4     Yash   D     80
# <bound method NDFrame._add_numeric_operations.<locals>.sum of    Roll no     Name Div  Marks
# 0        1   Aditya   A     98
# 1        2  Shubham   B     87
# 2        3   Jayesh   C     79
# 3        4     Yash   D     80>

# %%
df.describe()
# Out:
#         Roll no     Marks
# count  4.000000   4.00000
# mean   2.500000  86.00000
# std    1.290994   8.75595
# min    1.000000  79.00000
# 25%    1.750000  79.75000
# 50%    2.500000  83.50000
# 75%    3.250000  89.75000
# max    4.000000  98.00000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['Roll no'].plot(kind='hist', bins=20, title='Roll no')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['Marks'].plot(kind='hist', bins=20, title='Marks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Roll no', y='Marks', s=32, alpha=.8)
# ...

# %%
df.describe(include='object')
# Out:
#           Name Div
# count        4   4
# unique       4   4
# top     Aditya   A
# freq         1   1
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Div').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
# ...

# %%
df.shape
# Out:
# (4, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  4 non-null      int64
#  1   Name     4 non-null      object
#  2   Div      4 non-null      object
#  3   Marks    4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of    Roll no     Name Div  Marks
# 0        1   Aditya   A     98
# 1        2  Shubham   B     87
# 2        3   Jayesh   C     79
# 3        4     Yash   D     80>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.value_counts()
# Out:
# Roll no  Name     Div  Marks
# 1        Aditya   A    98       1
# 2        Shubham  B    87       1
# 3        Jayesh   C    79       1
# 4        Yash     D    80       1
# dtype: int64

# %%
df['Name'].value_counts()
# Out:
# Aditya     1
# Shubham    1
# Jayesh     1
# Yash       1
# Name: Name, dtype: int64

# %%
correlation=df.corr()
# Out:
# <ipython-input-28-0c9b4bd1cb53>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True,fmt='.3f',cmap='flare')
# Out:
# <Axes: >

# %%
df.var()
# Out:
# <ipython-input-33-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Roll no     1.666667
# Marks      76.666667
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-35-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Roll no     2.5
# Marks      86.0
# dtype: float64

# %%
df['Marks'].var
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.var of 0    98
# 1    87
# 2    79
# 3    80
# Name: Marks, dtype: int64>

# %%
df.cov()
# Out:
# <ipython-input-47-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#            Roll no      Marks
# Roll no   1.666667 -10.333333
# Marks   -10.333333  76.666667
